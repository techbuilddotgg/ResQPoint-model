# %% [markdown]
# By leveraging advanced layers like the Moisture Index, Moisture Stress (NDMI), and NDWI, our solution offers a comprehensive understanding of both soil moisture levels and water body conditions, enabling highly accurate flood detection at early stages. These indicators provide valuable insights into areas at risk, allowing for proactive intervention before disaster strikes. Existing validated models already utilize these data layers effectively, and with continued development, we aim to refine these predictions even further. The result will be a cutting-edge flood prediction system capable of delivering precise, real-time alerts that drive faster, more efficient response strategies, minimizing damage, and saving lives. By enhancing flood forecasting capabilities, we are not just improving preparedness—we are revolutionizing how communities respond to natural disasters.

# %%
from IPython.display import Image

# %%
for i in range(1,4):
    img_path = 's_'+str(i)+'.jpg'
    display(Image(filename=img_path))
